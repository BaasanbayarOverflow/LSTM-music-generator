# %%
from music21 import *

environment.set('musescoreDirectPNGPath', 'C:\\Program Files\\MuseScore 3\\bin\\MuseScore3.exe')

# %%
music = converter.parse('weights/music_one_epoch.mid')
music.show()

# %%
music = converter.parse('weights/music_250_epoch.mid')
music.show()

# %%
music = converter.parse('weights/music_500_epoch.mid')
music.show()

# %%
music = converter.parse('raw_data/album_72_1_(c)yogore.mid')
music.show()

# %%
music = converter.parse('music.mid')
music.show()

# %%
music = converter.parse('weights/music_250_epochD.mid')
music.show()
